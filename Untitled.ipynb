# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress

# %%
e_path = ("data/FRED_earnings.csv")
earning_df = pd.read_csv(e_path)
earned_df = earning_df.rename(columns = {"CAEREA": "CA Real Estate Earnings(Thousands of Dollars)"})
earned_df.head()
# Out:
#          DATE  CA Real Estate Earnings(Thousands of Dollars)
# 0  2017-10-01                                     57466164.0
# 1  2018-01-01                                     60105952.0
# 2  2018-04-01                                     61913336.0
# 3  2018-07-01                                     63011972.0
# 4  2018-10-01                                     63635700.0

# %%
#Plot Data
#Set axes
x_values = [2017.833, 2018.083, 2018.333, 2018.583, 2018.833,
            2019.083, 2019.333, 2019.583, 2019.833,
           2020.083, 2020.333, 2020.583, 2020.833,
           2021.083, 2021.333, 2021.583, 2021.833,
           2022.083, 2022.333, 2022.583, 2022.833]
y_values = earned_df["CA Real Estate Earnings(Thousands of Dollars)"]

#Retrieve line regression information
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = []
for x in x_values:
    regress = slope * x + intercept
    regress_values.append(regress)
    
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (2018, 65000000), color = "red")
ax=plt.gca()

plt.scatter(x_values, y_values, marker='o', label = "California" )
plt.xlabel("DATE")
plt.ylabel("CA Real Estate Earnings(Thousands of Dollars)")
plt.title("CA Rental and Leasing Earnings in California")
plt.legend()
plt.show()
    
print("Regression Line Equation: y = {:.2f}x + {:.2f}".format(slope, intercept))
print("Correlation Coefficient:", rvalue)
# Out:
# Regression Line Equation: y = 4506584.27x + -9032488571.65
# Correlation Coefficient: 0.9178036966871206

# %%
# # Plotting the data
# # Select one data point for each year
# selected_years = ['2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31']
# selected_data = earned_df[['RegionName'] + selected_years]

# # Plotting the scatter diagram for California
# plt.figure(figsize=(12, 6))
# california_prices = selected_data[selected_data['RegionName'] == 'California'].values.flatten()[1:].astype(float)
# plt.scatter(selected_years, california_prices, label='California')



# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
# regress_values = (y_values -intercept) / slope 
# xaxis = np.arange(len(x_values))
# print(xaxis)
plt.scatter(x_values, y_values, marker='o', label = "California" )
# plt.plot(x_values, regress_values, "r-")

# plt.annotate(line_eq, (5.8, 0.8), color = "red")
# plt.figure(figsize=(12,8))
plt.xlabel("DATE")
plt.ylabel("CA Real Estate Earnings(Thousands of Dollars)")
plt.title("CA Rental and Leasing Earnings in California")
plt.xticks(x_values, rotation='vertical')
plt.legend()
# plt.show()

# %%
Med_sale_path = ("data/California_yearly_med_sale_price_value.csv")
med_sale_df = pd.read_csv(Med_sale_path)
new_med_sale_df = med_sale_df.drop(med_sale_df.columns[48:52],axis=1)
new_med_sale_df = med_sale_df.drop(med_sale_df.columns[0],axis=1)
new_med_sale_df.head()
# Out:
#   Month of Period End Month of Period End.1 Month of Period End.2  \
# 0              Feb-19                Mar-19                Apr-19
# 1               $543K                 $566K                 $582K
#
#   Month of Period End.3 Month of Period End.4 Month of Period End.5  \
# 0                May-19                Jun-19                Jul-19
# 1                 $586K                 $587K                 $577K
#
#   Month of Period End.6 Month of Period End.7 Month of Period End.8  \
# 0                Aug-19                Sep-19                Oct-19
# 1                 $566K                 $564K                 $576K
#
#   Month of Period End.9  ... Month of Period End.41 Month of Period End.42  \
# 0                Nov-19  ...                 Jul-22                 Aug-22
# 1                 $575K  ...                  $776K                  $757K
#
#   Month of Period End.43 Month of Period End.44 Month of Period End.45  \
# ...

# %%
clean_df = new_med_sale_df.iloc[:, ::3]
clean_df
# Out:
#   Month of Period End Month of Period End.3 Month of Period End.6  \
# 0              Feb-19                May-19                Aug-19
# 1               $543K                 $586K                 $566K
#
#   Month of Period End.9 Month of Period End.12 Month of Period End.15  \
# 0                Nov-19                 Feb-20                 May-20
# 1                 $575K                  $568K                  $566K
#
#   Month of Period End.18 Month of Period End.21 Month of Period End.24  \
# 0                 Aug-20                 Nov-20                 Feb-21
# 1                  $634K                  $652K                  $664K
#
#   Month of Period End.27 Month of Period End.30 Month of Period End.33  \
# 0                 May-21                 Aug-21                 Nov-21
# 1                  $757K                  $745K                  $753K
#
#   Month of Period End.36 Month of Period End.39 Month of Period End.42  \
# ...

# %%
months = clean_df.loc[0,:]
values = clean_df.loc[1,:]





x_axis = np.arange(len(months))
y_axis = [543, 586, 566, 575, 568, 566, 634, 652, 664, 757, 745, 753, 755, 835, 757, 733, 704]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = slope * x_axis + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(months, values, marker='o', label = "California" )
plt.plot(x_axis, regress_values, "r-")
# plt.annotate(line_eq, (5.8, 0.8), color = "red")
# plt.figure(figsize=(12,8))
plt.xlabel("Months")
plt.ylabel("Median Price")
plt.title("Median Sales Price")
plt.xticks(months, rotation='vertical')
plt.legend()
plt.show()

# %%
pct_path= ("data/California_yearly_med_sale_price_yoy.csv")
pct_sales_df = pd.read_csv(pct_path)
pct_sales_df = pct_sales_df.drop(pct_sales_df.columns[48:52],axis=1)
pct_sales_df = pct_sales_df.drop(pct_sales_df.columns[0],axis=1)
pct_sales_df
# Out:
#   Month of Period End Month of Period End.1 Month of Period End.2  \
# 0              Feb-19                Mar-19                Apr-19
# 1              -0.70%                -1.30%                 0.00%
#
#   Month of Period End.3 Month of Period End.4 Month of Period End.5  \
# 0                May-19                Jun-19                Jul-19
# 1                -1.60%                -1.50%                -1.50%
#
#   Month of Period End.6 Month of Period End.7 Month of Period End.8  \
# 0                Aug-19                Sep-19                Oct-19
# 1                -2.10%                -1.40%                 0.00%
#
#   Month of Period End.9  ... Month of Period End.37 Month of Period End.38  \
# 0                Nov-19  ...                 Mar-22                 Apr-22
# 1                 1.10%  ...                 14.90%                 13.10%
#
#   Month of Period End.39 Month of Period End.40 Month of Period End.41  \
# ...

# %%
clean_sales_df = pct_sales_df.iloc[:, ::3]
clean_sales_df
# Out:
#   Month of Period End Month of Period End.3 Month of Period End.6  \
# 0              Feb-19                May-19                Aug-19
# 1              -0.70%                -1.60%                -2.10%
#
#   Month of Period End.9 Month of Period End.12 Month of Period End.15  \
# 0                Nov-19                 Feb-20                 May-20
# 1                 1.10%                  4.70%                 -3.40%
#
#   Month of Period End.18 Month of Period End.21 Month of Period End.24  \
# 0                 Aug-20                 Nov-20                 Feb-21
# 1                 12.10%                 13.40%                 16.90%
#
#   Month of Period End.27 Month of Period End.30 Month of Period End.33  \
# 0                 May-21                 Aug-21                 Nov-21
# 1                 33.60%                 17.60%                 15.60%
#
#   Month of Period End.36 Month of Period End.39 Month of Period End.42  \
# ...

# %%
months = pct_sales_df.loc[0,:]
values = clean_df.loc[1,:]





x_axis = np.arange(len(months))
y_axis = [543, 586, 566, 575, 568, 566, 634, 652, 664, 757, 745, 753, 755, 835, 757, 733, 704]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = slope * x_axis + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(months, values, marker='o', label = "California" )
plt.plot(x_axis, regress_values, "r-")
# plt.annotate(line_eq, (5.8, 0.8), color = "red")
# plt.figure(figsize=(12,8))
plt.xlabel("Months")
plt.ylabel("Median Price")
plt.title("Median Sales Price")
plt.xticks(months, rotation='vertical')
plt.legend()
plt.show()

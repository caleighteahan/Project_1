# %%
import pandas as pd
import numpy as np
import matplotlb.pyplot as plt

# %%
path = ("data/redfin_data.csv")
redfin_df = pd.read_csv(path)
redfin_df.head()
# Out:
#       Region Month of Period End Median Sale Price Median Sale Price MoM   \
# 0   National              Feb-19             $276K                  1.30%
# 1   National              Mar-19             $284K                  2.80%
# 2   National              Apr-19             $290K                  2.20%
# 3   National              May-19             $298K                  2.90%
# 4   National              Jun-19             $303K                  1.40%
#
#   Median Sale Price YoY  Homes Sold Homes Sold MoM  Homes Sold YoY   \
# 0                  2.90%    371,041          11.40%          -0.20%
# 1                  2.20%    486,241          31.00%          -5.10%
# 2                  3.00%    546,481          12.40%           1.90%
# 3                  3.70%    642,068          17.50%           2.80%
# 4                  3.40%    620,446          -3.40%          -6.00%
#
#   New Listings New Listings MoM  New Listings YoY   Inventory Inventory MoM   \
# ...

# %%
zillow_path = ("data/Metro_zori_sm_month.csv")
zillow_df = pd.read_csv(zillow_path)
zillow_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName    3/31/2015  \
# 0    102001         0    United States    country       NaN  1316.882137
# 1    394913         1     New York, NY        msa        NY  2443.764214
# 2    753899         2  Los Angeles, CA        msa        CA  1921.951938
# 3    394463         3      Chicago, IL        msa        IL  1490.453763
# 4    394514         4       Dallas, TX        msa        TX  1156.562026
#
#      4/30/2015    5/31/2015    6/30/2015    7/31/2015  ...    7/31/2022  \
# 0  1327.077746  1336.985344  1347.189723  1353.394167  ...  1987.491300
# 1  2464.719370  2483.196870  2500.971887  2512.718350  ...  3207.491920
# 2  1935.567889  1948.902894  1961.209437  1978.339689  ...  2916.787977
# 3  1502.135150  1513.653098  1523.141742  1529.525405  ...  1926.675734
# 4  1167.566988  1178.805865  1187.481860  1193.257396  ...  1822.737036
#
#      8/31/2022    9/30/2022   10/31/2022   11/30/2022   12/31/2022  \
# ...

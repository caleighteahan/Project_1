# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = ("data/redfin_data.csv")
redfin_df = pd.read_csv(path)
redfin_df.head()
# Out:
#       Region Month of Period End Median Sale Price Median Sale Price MoM   \
# 0   National              Feb-19             $276K                  1.30%
# 1   National              Mar-19             $284K                  2.80%
# 2   National              Apr-19             $290K                  2.20%
# 3   National              May-19             $298K                  2.90%
# 4   National              Jun-19             $303K                  1.40%
#
#   Median Sale Price YoY  Homes Sold Homes Sold MoM  Homes Sold YoY   \
# 0                  2.90%    371,041          11.40%          -0.20%
# 1                  2.20%    486,241          31.00%          -5.10%
# 2                  3.00%    546,481          12.40%           1.90%
# 3                  3.70%    642,068          17.50%           2.80%
# 4                  3.40%    620,446          -3.40%          -6.00%
#
#   New Listings New Listings MoM  New Listings YoY   Inventory Inventory MoM   \
# ...

# %%
zillow_path = ("data/Metro_zori_sm_month.csv")
zillow_df = pd.read_csv(zillow_path)
zillow_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName    3/31/2015  \
# 0    102001         0    United States    country       NaN  1316.882137
# 1    394913         1     New York, NY        msa        NY  2443.764214
# 2    753899         2  Los Angeles, CA        msa        CA  1921.951938
# 3    394463         3      Chicago, IL        msa        IL  1490.453763
# 4    394514         4       Dallas, TX        msa        TX  1156.562026
#
#      4/30/2015    5/31/2015    6/30/2015    7/31/2015  ...    7/31/2022  \
# 0  1327.077746  1336.985344  1347.189723  1353.394167  ...  1987.491300
# 1  2464.719370  2483.196870  2500.971887  2512.718350  ...  3207.491920
# 2  1935.567889  1948.902894  1961.209437  1978.339689  ...  2916.787977
# 3  1502.135150  1513.653098  1523.141742  1529.525405  ...  1926.675734
# 4  1167.566988  1178.805865  1187.481860  1193.257396  ...  1822.737036
#
#      8/31/2022    9/30/2022   10/31/2022   11/30/2022   12/31/2022  \
# ...

# %%
med_path = ("data/med_sale_price.csv")
med_sale_df = pd.read_csv(med_path)
med_sale_df.head()
# Out:
#                         Region January 2019 February 2019 March 2019  \
# 0                     National        $272K         $276K      $284K
# 1        Boston, MA metro area        $473K         $455K      $475K
# 2       Chicago, IL metro area        $225K         $233K      $243K
# 3   Los Angeles, CA metro area        $595K         $602K      $625K
# 4  Philadelphia, PA metro area        $185K         $185K      $199K
#
#   April 2019 May 2019 June 2019 July 2019 August 2019 September 2019  ...  \
# 0      $290K    $298K     $303K     $299K       $297K          $292K  ...
# 1      $485K    $520K     $530K     $530K       $515K          $490K  ...
# 2      $255K    $262K     $266K     $262K       $255K          $244K  ...
# 3      $626K    $630K     $638K     $650K       $640K          $641K  ...
# 4      $210K    $218K     $236K     $225K       $222K          $200K  ...
#
#   Unnamed: 126 Unnamed: 127 Unnamed: 128 Unnamed: 129 Unnamed: 130  \
# ...

# %%
print(med_sale_df).T
# Out:
#                           Region January 2019 February 2019 March 2019  \
# 0                       National        $272K         $276K      $284K
# 1          Boston, MA metro area        $473K         $455K      $475K
# 2         Chicago, IL metro area        $225K         $233K      $243K
# 3     Los Angeles, CA metro area        $595K         $602K      $625K
# 4    Philadelphia, PA metro area        $185K         $185K      $199K
# 5         Seattle, WA metro area        $518K         $540K      $555K
# 6      Washington, DC metro area        $385K         $387K      $405K
# 7       San Francisco County, CA      $1,200K       $1,311K    $1,425K
# 8              San Francisco, CA      $1,200K       $1,311K    $1,425K
# 9   San Francisco, CA metro area      $1,225K       $1,285K    $1,400K
# 10       South San Francisco, CA        $963K         $957K    $1,000K
#
#    April 2019 May 2019 June 2019 July 2019 August 2019 September 2019  ...  \
# ...

# %%
Med_sale_path = ("data/California_yearly_med_sale_price_yoy.csv")
med_sale_df = pd.read_csv(Med_sale_path)
new_med_sale_df = med_sale_df.drop(med_sale_df.columns[48:52],axis=1)
new_med_sale_df.head()
# Out:
#    Unnamed: 0 Month of Period End Month of Period End.1 Month of Period End.2  \
# 0      Region              Feb-19                Mar-19                Apr-19
# 1  California              -0.70%                -1.30%                 0.00%
#
#   Month of Period End.3 Month of Period End.4 Month of Period End.5  \
# 0                May-19                Jun-19                Jul-19
# 1                -1.60%                -1.50%                -1.50%
#
#   Month of Period End.6 Month of Period End.7 Month of Period End.8  ...  \
# 0                Aug-19                Sep-19                Oct-19  ...
# 1                -2.10%                -1.40%                 0.00%  ...
#
#   Month of Period End.37 Month of Period End.38 Month of Period End.39  \
# 0                 Mar-22                 Apr-22                 May-22
# 1                 14.90%                 13.10%                 10.40%
#
#   Month of Period End.40 Month of Period End.41 Month of Period End.42  \
# ...

# %%
plt.figure(figsize=(12,8))
plt.plot()

# %%
California_yearly_med_sale_price_yoy
